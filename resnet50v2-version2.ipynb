# %% [markdown]
# > Author: Bui Tran Gia Bao - 104177225

# %% [markdown]
# # **Importing libraries and defining data directories**

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.data import Dataset
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

data_dir = "/kaggle/input/d/solar11781/bird-species/"
train_images_dir = os.path.join(data_dir, "Train/")
test_images_dir = os.path.join(data_dir, "Test/")
train_txt = os.path.join(data_dir, "train.txt")
test_txt = os.path.join(data_dir, "test.txt")

# %% [markdown]
# # **Preprocessing data**

# %%
def load_data_from_txt(txt_file, images_dir):
    images, labels = [], []

    with open(txt_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            image_name, class_label = line.strip().split()
            image_path = os.path.join(images_dir, image_name)
            
            if os.path.exists(image_path):
                img = load_img(image_path, target_size=(224, 224))
                img_array = preprocess_input(img_to_array(img))
                
                images.append(img_array)
                labels.append(int(class_label))
            else:
                print(f"Error: Image {image_path} not found.")

    # Convert to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels


train_images, train_labels = load_data_from_txt(train_txt, train_images_dir)
test_images, test_labels = load_data_from_txt(test_txt, test_images_dir)

# Split the train data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.3, random_state=42
)

# Oversample the training dataset
ros = RandomOverSampler()
train_images_resampled, train_labels_resampled = ros.fit_resample(train_images.reshape((train_images.shape[0], -1)), train_labels)
train_images_resampled = train_images_resampled.reshape((-1, 224, 224, 3))

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

train_images_augmented = train_datagen.flow(train_images_resampled, train_labels_resampled, batch_size=32)


# Convert labels to one-hot encoding
train_labels = to_categorical(train_labels_resampled, num_classes=200)
val_labels = to_categorical(val_labels, num_classes=200)
test_labels = to_categorical(test_labels, num_classes=200)

# Create TensorFlow datasets
batch_size = 32
train_ds = Dataset.from_tensor_slices((train_images_resampled, train_labels)).shuffle(len(train_images_resampled)).batch(batch_size)
val_ds = Dataset.from_tensor_slices((val_images, val_labels)).batch(batch_size)
test_ds = Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

# Print the number of images per class to check for imbalance
unique_train, counts_train = np.unique(train_labels.argmax(axis=1), return_counts=True)
train_class_counts = dict(zip(unique_train, counts_train))
print('Training set class counts:', train_class_counts)

unique_test, counts_test = np.unique(test_labels.argmax(axis=1), return_counts=True)
test_class_counts = dict(zip(unique_test, counts_test))
print('Test set class counts:', test_class_counts)
# Out:
# Training set class counts: {0: 25, 1: 25, 2: 25, 3: 25, 4: 25, 5: 25, 6: 25, 7: 25, 8: 25, 9: 25, 10: 25, 11: 25, 12: 25, 13: 25, 14: 25, 15: 25, 16: 25, 17: 25, 18: 25, 19: 25, 20: 25, 21: 25, 22: 25, 23: 25, 24: 25, 25: 25, 26: 25, 27: 25, 28: 25, 29: 25, 30: 25, 31: 25, 32: 25, 33: 25, 34: 25, 35: 25, 36: 25, 37: 25, 38: 25, 39: 25, 40: 25, 41: 25, 42: 25, 43: 25, 44: 25, 45: 25, 46: 25, 47: 25, 48: 25, 49: 25, 50: 25, 51: 25, 52: 25, 53: 25, 54: 25, 55: 25, 56: 25, 57: 25, 58: 25, 59: 25, 60: 25, 61: 25, 62: 25, 63: 25, 64: 25, 65: 25, 66: 25, 67: 25, 68: 25, 69: 25, 70: 25, 71: 25, 72: 25, 73: 25, 74: 25, 75: 25, 76: 25, 77: 25, 78: 25, 79: 25, 80: 25, 81: 25, 82: 25, 83: 25, 84: 25, 85: 25, 86: 25, 87: 25, 88: 25, 89: 25, 90: 25, 91: 25, 92: 25, 93: 25, 94: 25, 95: 25, 96: 25, 97: 25, 98: 25, 99: 25, 100: 25, 101: 25, 102: 25, 103: 25, 104: 25, 105: 25, 106: 25, 107: 25, 108: 25, 109: 25, 110: 25, 111: 25, 112: 25, 113: 25, 114: 25, 115: 25, 116: 25, 117: 25, 118: 25, 119: 25, 120: 25, 121: 25, 122: 25, 123: 25, 124: 25, 125: 25, 126: 25, 127: 25, 128: 25, 129: 25, 130: 25, 131: 25, 132: 25, 133: 25, 134: 25, 135: 25, 136: 25, 137: 25, 138: 25, 139: 25, 140: 25, 141: 25, 142: 25, 143: 25, 144: 25, 145: 25, 146: 25, 147: 25, 148: 25, 149: 25, 150: 25, 151: 25, 152: 25, 153: 25, 154: 25, 155: 25, 156: 25, 157: 25, 158: 25, 159: 25, 160: 25, 161: 25, 162: 25, 163: 25, 164: 25, 165: 25, 166: 25, 167: 25, 168: 25, 169: 25, 170: 25, 171: 25, 172: 25, 173: 25, 174: 25, 175: 25, 176: 25, 177: 25, 178: 25, 179: 25, 180: 25, 181: 25, 182: 25, 183: 25, 184: 25, 185: 25, 186: 25, 187: 25, 188: 25, 189: 25, 190: 25, 191: 25, 192: 25, 193: 25, 194: 25, 195: 25, 196: 25, 197: 25, 198: 25, 199: 25}
# Test set class counts: {0: 7, 1: 5, 2: 5, 3: 7, 4: 5, 5: 6, 6: 7, 7: 6, 8: 5, 9: 5, 10: 5, 11: 6, 12: 5, 13: 7, 14: 6, 15: 6, 16: 5, 17: 4, 18: 7, 19: 7, 20: 6, 21: 4, 22: 5, 23: 4, 24: 6, 25: 5, 26: 6, 27: 7, 28: 5, 29: 6, 30: 7, 31: 6, 32: 7, 33: 5, 34: 6, 35: 8, 36: 7, 37: 7, 38: 6, 39: 6, 40: 7, 41: 5, 42: 7, 43: 4, 44: 6, 45: 7, 46: 5, 47: 7, 48: 7, 49: 7, 50: 6, 51: 6, 52: 7, 53: 6, 54: 5, 55: 4, 56: 4, 57: 5, 58: 5, 59: 7, 60: 5, 61: 5, 62: 4, 63: 5, 64: 6, 65: 6, 66: 5, 67: 5, 68: 7, 69: 6, 70: 6, 71: 6, 72: 7, 73: 7, 74: 7, 75: 5, 76: 7, 77: 7, 78: 6, 79: 5, 80: 7, 81: 7, 82: 7, 83: 4, 84: 6, 85: 7, 86: 5, 87: 6, 88: 7, 89: 6, 90: 6, 91: 6, 92: 7, 93: 7, 94: 5, 95: 7, 96: 7, 97: 6, 98: 6, 99: 6, 100: 5, 101: 7, 102: 5, 103: 6, 104: 4, 105: 6, 106: 5, 107: 6, 108: 6, 109: 5, 110: 7, 111: 6, 112: 7, 113: 7, 114: 7, 115: 6, 116: 7, 117: 6, 118: 6, 119: 7, 120: 7, 121: 5, 122: 7, 123: 7, 124: 7, 125: 6, 126: 7, 127: 5, 128: 8, 129: 4, 130: 8, 131: 5, 132: 7, 133: 7, 134: 5, 135: 5, 136: 6, 137: 7, 138: 5, 139: 4, 140: 7, 141: 4, 142: 8, 143: 7, 144: 5, 145: 5, 146: 5, 147: 7, 148: 6, 149: 5, 150: 5, 151: 7, 152: 7, 153: 7, 154: 7, 155: 7, 156: 6, 157: 6, 158: 7, 159: 4, 160: 7, 161: 7, 162: 7, 163: 5, 164: 6, 165: 7, 166: 5, 167: 6, 168: 5, 169: 7, 170: 4, 171: 6, 172: 6, 173: 6, 174: 6, 175: 7, 176: 7, 177: 5, 178: 6, 179: 7, 180: 6, 181: 4, 182: 7, 183: 6, 184: 7, 185: 7, 186: 6, 187: 8, 188: 7, 189: 4, 190: 6, 191: 8, 192: 7, 193: 5, 194: 7, 195: 5, 196: 6, 197: 5, 198: 7, 199: 5}

# %% [markdown]
# # **Training the model**

# %%
NUM_CLASSES = 200
IMAGE_RESIZE = 224
POOLING_AVERAGE = 'avg'
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'
LOSS_METRICS = ['accuracy']
NUM_EPOCHS = 100
LEARNING_RATE = 0.0001
best_model = '/kaggle/working/bird-model.keras'
checkpoint = '/kaggle/working/checkpoint_model_epoch_{epoch:02d}.keras'
callbacks = [
    ModelCheckpoint(best_model, verbose=1, save_best_only=True, monitor='val_accuracy'),
    ModelCheckpoint(checkpoint, verbose=1, save_weights_only=False, save_freq=5 * len(train_ds), save_best_only=False),
    ReduceLROnPlateau(monitor='val_accuracy', patience=2, factor=0.2, verbose=1, min_lr=1e-9),
    EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, restore_best_weights=True)
]

# %%
# Build the model.
model = Sequential()

# Using ResNet50 as feature extractor
resnet= ResNet50V2(include_top=False,
                 input_shape=(IMAGE_RESIZE, IMAGE_RESIZE, 3),
                 pooling=POOLING_AVERAGE, weights='imagenet')

for layer in resnet.layers[:-10]:
    layer.trainable = False
for layer in resnet.layers[-10:]:
    layer.trainable = True

model.add(resnet)
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation=DENSE_LAYER_ACTIVATION, kernel_regularizer=l2(0.01)))
model.build((None, IMAGE_RESIZE, IMAGE_RESIZE, 3))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50v2 (Functional)         │ (None, 2048)           │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 200)            │        13,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,848,328 (90.97 MB)
#  Trainable params: 3,698,568 (14.11 MB)
#  Non-trainable params: 20,149,760 (76.87 MB)

# %%
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss=OBJECTIVE_FUNCTION, metrics=LOSS_METRICS)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729406127.561692      64 service.cc:145] XLA service 0x7c7c28113ba0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729406127.561741      64 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   4/157 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.0046 - loss: 9.6861
# I0000 00:00:1729406137.119256      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.0064 - loss: 9.3829
# Epoch 1: val_accuracy improved from -inf to 0.01656, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 152ms/step - accuracy: 0.0064 - loss: 9.3814 - val_accuracy: 0.0166 - val_loss: 8.7023 - learning_rate: 1.0000e-04
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0154 - loss: 8.5200
# Epoch 2: val_accuracy improved from 0.01656 to 0.03313, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0154 - loss: 8.5190 - val_accuracy: 0.0331 - val_loss: 8.0323 - learning_rate: 1.0000e-04
# Epoch 3/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0226 - loss: 7.8691
# Epoch 3: val_accuracy improved from 0.03313 to 0.06418, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0226 - loss: 7.8676 - val_accuracy: 0.0642 - val_loss: 7.5209 - learning_rate: 1.0000e-04
# Epoch 4/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0399 - loss: 7.3831
# Epoch 4: val_accuracy improved from 0.06418 to 0.10628, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0399 - loss: 7.3819 - val_accuracy: 0.1063 - val_loss: 7.1005 - learning_rate: 1.0000e-04
# Epoch 5/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0615 - loss: 6.9486
# Epoch 5: saving model to /kaggle/working/checkpoint_model_epoch_05.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0615 - loss: 6.9482
# Epoch 5: val_accuracy improved from 0.10628 to 0.11801, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.0615 - loss: 6.9479 - val_accuracy: 0.1180 - val_loss: 6.7718 - learning_rate: 1.0000e-04
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0790 - loss: 6.6588
# Epoch 6: val_accuracy improved from 0.11801 to 0.16011, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0790 - loss: 6.6583 - val_accuracy: 0.1601 - val_loss: 6.4331 - learning_rate: 1.0000e-04
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0894 - loss: 6.3505
# Epoch 7: val_accuracy improved from 0.16011 to 0.18634, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0894 - loss: 6.3501 - val_accuracy: 0.1863 - val_loss: 6.1745 - learning_rate: 1.0000e-04
# Epoch 8/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1118 - loss: 6.0832
# Epoch 8: val_accuracy improved from 0.18634 to 0.19807, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.1119 - loss: 6.0824 - val_accuracy: 0.1981 - val_loss: 5.9275 - learning_rate: 1.0000e-04
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1224 - loss: 5.8560
# Epoch 9: val_accuracy improved from 0.19807 to 0.22360, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.1225 - loss: 5.8555 - val_accuracy: 0.2236 - val_loss: 5.7444 - learning_rate: 1.0000e-04
# Epoch 10/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1686 - loss: 5.5988
# Epoch 10: saving model to /kaggle/working/checkpoint_model_epoch_10.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.1685 - loss: 5.5986
# Epoch 10: val_accuracy improved from 0.22360 to 0.23948, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.1685 - loss: 5.5985 - val_accuracy: 0.2395 - val_loss: 5.5599 - learning_rate: 1.0000e-04
# Epoch 11/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1706 - loss: 5.4170
# Epoch 11: val_accuracy improved from 0.23948 to 0.26432, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.1707 - loss: 5.4163 - val_accuracy: 0.2643 - val_loss: 5.3865 - learning_rate: 1.0000e-04
# Epoch 12/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2019 - loss: 5.2011
# Epoch 12: val_accuracy improved from 0.26432 to 0.26570, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2018 - loss: 5.2008 - val_accuracy: 0.2657 - val_loss: 5.2157 - learning_rate: 1.0000e-04
# Epoch 13/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2234 - loss: 5.0426
# Epoch 13: val_accuracy improved from 0.26570 to 0.29055, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2234 - loss: 5.0422 - val_accuracy: 0.2905 - val_loss: 5.1124 - learning_rate: 1.0000e-04
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2466 - loss: 4.8192
# Epoch 14: val_accuracy improved from 0.29055 to 0.30504, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2466 - loss: 4.8191 - val_accuracy: 0.3050 - val_loss: 5.0050 - learning_rate: 1.0000e-04
# Epoch 15/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2594 - loss: 4.6904
# Epoch 15: saving model to /kaggle/working/checkpoint_model_epoch_15.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2594 - loss: 4.6904
# Epoch 15: val_accuracy improved from 0.30504 to 0.31263, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.2594 - loss: 4.6904 - val_accuracy: 0.3126 - val_loss: 4.9074 - learning_rate: 1.0000e-04
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3020 - loss: 4.5250
# Epoch 16: val_accuracy improved from 0.31263 to 0.31470, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3020 - loss: 4.5249 - val_accuracy: 0.3147 - val_loss: 4.7815 - learning_rate: 1.0000e-04
# Epoch 17/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3005 - loss: 4.4399
# Epoch 17: val_accuracy improved from 0.31470 to 0.32229, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.3006 - loss: 4.4391 - val_accuracy: 0.3223 - val_loss: 4.7050 - learning_rate: 1.0000e-04
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3178 - loss: 4.2882
# Epoch 18: val_accuracy improved from 0.32229 to 0.34576, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3178 - loss: 4.2882 - val_accuracy: 0.3458 - val_loss: 4.6462 - learning_rate: 1.0000e-04
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3348 - loss: 4.1759
# Epoch 19: val_accuracy did not improve from 0.34576
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.3348 - loss: 4.1758 - val_accuracy: 0.3375 - val_loss: 4.6221 - learning_rate: 1.0000e-04
# Epoch 20/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3493 - loss: 4.0724
# Epoch 20: saving model to /kaggle/working/checkpoint_model_epoch_20.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3494 - loss: 4.0720
# Epoch 20: val_accuracy improved from 0.34576 to 0.34921, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.3495 - loss: 4.0717 - val_accuracy: 0.3492 - val_loss: 4.5502 - learning_rate: 1.0000e-04
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3615 - loss: 3.9556
# Epoch 21: val_accuracy did not improve from 0.34921
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.3616 - loss: 3.9554 - val_accuracy: 0.3375 - val_loss: 4.5165 - learning_rate: 1.0000e-04
# Epoch 22/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3949 - loss: 3.7958
# Epoch 22: val_accuracy did not improve from 0.34921
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.3948 - loss: 3.7962 - val_accuracy: 0.3389 - val_loss: 4.4805 - learning_rate: 1.0000e-04
# Epoch 23/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4027 - loss: 3.7284
# Epoch 23: val_accuracy improved from 0.34921 to 0.36094, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.4028 - loss: 3.7280 - val_accuracy: 0.3609 - val_loss: 4.4242 - learning_rate: 2.0000e-05
# Epoch 24/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4326 - loss: 3.6374
# Epoch 24: val_accuracy improved from 0.36094 to 0.36577, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.4325 - loss: 3.6377 - val_accuracy: 0.3658 - val_loss: 4.4098 - learning_rate: 2.0000e-05
# Epoch 25/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4263 - loss: 3.6027
# Epoch 25: saving model to /kaggle/working/checkpoint_model_epoch_25.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4264 - loss: 3.6027
# Epoch 25: val_accuracy improved from 0.36577 to 0.36784, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.4264 - loss: 3.6028 - val_accuracy: 0.3678 - val_loss: 4.3886 - learning_rate: 2.0000e-05
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4398 - loss: 3.6251
# Epoch 26: val_accuracy improved from 0.36784 to 0.36922, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.4398 - loss: 3.6250 - val_accuracy: 0.3692 - val_loss: 4.3727 - learning_rate: 2.0000e-05
# Epoch 27/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4477 - loss: 3.5572
# Epoch 27: val_accuracy did not improve from 0.36922
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4477 - loss: 3.5574 - val_accuracy: 0.3520 - val_loss: 4.3776 - learning_rate: 2.0000e-05
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4306 - loss: 3.5767
# Epoch 28: val_accuracy did not improve from 0.36922
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4306 - loss: 3.5766 - val_accuracy: 0.3671 - val_loss: 4.3566 - learning_rate: 2.0000e-05
# Epoch 29/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4461 - loss: 3.5668
# Epoch 29: val_accuracy did not improve from 0.36922
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4460 - loss: 3.5668 - val_accuracy: 0.3678 - val_loss: 4.3563 - learning_rate: 4.0000e-06
# Epoch 30/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4620 - loss: 3.5046
# Epoch 30: saving model to /kaggle/working/checkpoint_model_epoch_30.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4620 - loss: 3.5046
# Epoch 30: val_accuracy improved from 0.36922 to 0.37060, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.4620 - loss: 3.5046 - val_accuracy: 0.3706 - val_loss: 4.3528 - learning_rate: 4.0000e-06
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4431 - loss: 3.5162
# Epoch 31: val_accuracy did not improve from 0.37060
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4431 - loss: 3.5162 - val_accuracy: 0.3699 - val_loss: 4.3497 - learning_rate: 4.0000e-06
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4550 - loss: 3.5019
# Epoch 32: val_accuracy did not improve from 0.37060
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4550 - loss: 3.5020 - val_accuracy: 0.3706 - val_loss: 4.3474 - learning_rate: 4.0000e-06
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4633 - loss: 3.4861
# Epoch 33: val_accuracy did not improve from 0.37060
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4633 - loss: 3.4861 - val_accuracy: 0.3706 - val_loss: 4.3473 - learning_rate: 8.0000e-07
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4730 - loss: 3.4188
# Epoch 34: val_accuracy did not improve from 0.37060
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4729 - loss: 3.4191 - val_accuracy: 0.3706 - val_loss: 4.3450 - learning_rate: 8.0000e-07
# Epoch 35/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4638 - loss: 3.4547
# Epoch 35: saving model to /kaggle/working/checkpoint_model_epoch_35.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4638 - loss: 3.4548
# Epoch 35: val_accuracy did not improve from 0.37060
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.4638 - loss: 3.4548 - val_accuracy: 0.3699 - val_loss: 4.3450 - learning_rate: 1.6000e-07
# Epoch 36/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4792 - loss: 3.4492
# Epoch 36: val_accuracy improved from 0.37060 to 0.37198, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.4790 - loss: 3.4494 - val_accuracy: 0.3720 - val_loss: 4.3453 - learning_rate: 1.6000e-07
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4596 - loss: 3.4717
# Epoch 37: val_accuracy improved from 0.37198 to 0.37336, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.4595 - loss: 3.4719 - val_accuracy: 0.3734 - val_loss: 4.3452 - learning_rate: 1.6000e-07
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4561 - loss: 3.4947
# Epoch 38: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4561 - loss: 3.4945 - val_accuracy: 0.3727 - val_loss: 4.3467 - learning_rate: 1.6000e-07
# Epoch 39/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4602 - loss: 3.5211
# Epoch 39: val_accuracy did not improve from 0.37336
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4601 - loss: 3.5210 - val_accuracy: 0.3720 - val_loss: 4.3459 - learning_rate: 1.6000e-07
# Epoch 40/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4587 - loss: 3.5060
# Epoch 40: saving model to /kaggle/working/checkpoint_model_epoch_40.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4587 - loss: 3.5060
# Epoch 40: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.4587 - loss: 3.5059 - val_accuracy: 0.3720 - val_loss: 4.3470 - learning_rate: 3.2000e-08
# Epoch 41/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4507 - loss: 3.5255
# Epoch 41: val_accuracy did not improve from 0.37336
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4507 - loss: 3.5252 - val_accuracy: 0.3706 - val_loss: 4.3460 - learning_rate: 3.2000e-08
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4581 - loss: 3.5073
# Epoch 42: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4582 - loss: 3.5072 - val_accuracy: 0.3734 - val_loss: 4.3454 - learning_rate: 6.4000e-09
# Epoch 43/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4589 - loss: 3.5130
# Epoch 43: val_accuracy did not improve from 0.37336
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4588 - loss: 3.5129 - val_accuracy: 0.3734 - val_loss: 4.3452 - learning_rate: 6.4000e-09
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4536 - loss: 3.5138
# Epoch 44: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4536 - loss: 3.5137 - val_accuracy: 0.3706 - val_loss: 4.3460 - learning_rate: 1.2800e-09
# Epoch 45/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4578 - loss: 3.4954
# Epoch 45: saving model to /kaggle/working/checkpoint_model_epoch_45.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4578 - loss: 3.4954
# Epoch 45: val_accuracy did not improve from 0.37336
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1e-09.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.4578 - loss: 3.4955 - val_accuracy: 0.3727 - val_loss: 4.3457 - learning_rate: 1.2800e-09
# Epoch 46/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4564 - loss: 3.4943
# Epoch 46: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4564 - loss: 3.4943 - val_accuracy: 0.3706 - val_loss: 4.3466 - learning_rate: 1.0000e-09
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4379 - loss: 3.5340
# Epoch 47: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4380 - loss: 3.5338 - val_accuracy: 0.3727 - val_loss: 4.3453 - learning_rate: 1.0000e-09
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4647 - loss: 3.4590
# Epoch 48: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4647 - loss: 3.4591 - val_accuracy: 0.3713 - val_loss: 4.3454 - learning_rate: 1.0000e-09
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4786 - loss: 3.4225
# Epoch 49: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4786 - loss: 3.4227 - val_accuracy: 0.3720 - val_loss: 4.3450 - learning_rate: 1.0000e-09
# Epoch 50/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4768 - loss: 3.4558
# Epoch 50: saving model to /kaggle/working/checkpoint_model_epoch_50.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4767 - loss: 3.4559
# Epoch 50: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.4767 - loss: 3.4561 - val_accuracy: 0.3727 - val_loss: 4.3454 - learning_rate: 1.0000e-09
# Epoch 51/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4710 - loss: 3.4556
# Epoch 51: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4709 - loss: 3.4557 - val_accuracy: 0.3713 - val_loss: 4.3463 - learning_rate: 1.0000e-09
# Epoch 52/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4620 - loss: 3.4601
# Epoch 52: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4621 - loss: 3.4602 - val_accuracy: 0.3713 - val_loss: 4.3450 - learning_rate: 1.0000e-09
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4439 - loss: 3.5634
# Epoch 53: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4439 - loss: 3.5633 - val_accuracy: 0.3713 - val_loss: 4.3459 - learning_rate: 1.0000e-09
# Epoch 54/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4631 - loss: 3.5199
# Epoch 54: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4632 - loss: 3.5196 - val_accuracy: 0.3699 - val_loss: 4.3463 - learning_rate: 1.0000e-09
# Epoch 55/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4726 - loss: 3.4546
# Epoch 55: saving model to /kaggle/working/checkpoint_model_epoch_55.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4724 - loss: 3.4552
# Epoch 55: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.4723 - loss: 3.4554 - val_accuracy: 0.3727 - val_loss: 4.3451 - learning_rate: 1.0000e-09
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4671 - loss: 3.4791
# Epoch 56: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4671 - loss: 3.4790 - val_accuracy: 0.3699 - val_loss: 4.3468 - learning_rate: 1.0000e-09
# Epoch 57/100
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4706 - loss: 3.4414
# Epoch 57: val_accuracy did not improve from 0.37336
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4705 - loss: 3.4416 - val_accuracy: 0.3713 - val_loss: 4.3452 - learning_rate: 1.0000e-09
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 37.

# %%
best_val_acc=max(history.history['val_accuracy'])
print(f"Best validation accuracy: {best_val_acc * 100:.2f}%")
# Out:
# Best validation accuracy: 37.34%

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Plot accuracy
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_ylim([0, 1])
axs[0].set_title('Training and Validation Accuracy')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].legend()
axs[0].grid(True)

# Plot loss
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Training and Validation Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Evaluation**

# %%
# Evaluate on test data
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Accuracy (Top-1 Accuracy): {test_accuracy * 100:.2f}%")

# Predict on the entire test dataset
y_pred = np.argmax(model.predict(test_ds), axis=-1)
y_true = np.concatenate([np.argmax(y, axis=-1) for _, y in test_ds], axis=0)

cm = confusion_matrix(y_true, y_pred)

# Calculate accuracy for each class
per_class_accuracy = cm.diagonal() / cm.sum(axis=1)

average_accuracy_per_class = np.mean(per_class_accuracy)
print(f"Average Accuracy per Class: {average_accuracy_per_class * 100:.2f}%")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.3791 - loss: 4.2691
# Test Accuracy (Top-1 Accuracy): 35.96%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step
# Average Accuracy per Class: 35.41%

# %%
def plot_and_predict(model, test_images, test_labels, filenames, num_images):
    plt.figure(figsize=(15, 10))
    rows = num_images // 6 + (num_images % 6 > 0)
    for i in range(num_images):
        idx = random.randint(0, len(test_images) - 1)
        img = test_images[idx]
        filename = filenames[idx]
        true_label = np.argmax(test_labels[idx])

        prediction = model.predict(np.expand_dims(img, axis=0))
        predicted_label = np.argmax(prediction)
        
        if true_label == predicted_label:
            color = 'green'
        else:
            color = 'red'

        plt.subplot(rows, 6, i + 1)
        plt.imshow((img + 1) / 2)
        plt.title(f"Filename: {filename}\nTrue: {true_label}, Prediction: {predicted_label}", color=color)
        plt.axis('off')

    plt.tight_layout(pad=0, h_pad=0, w_pad=1.0)
    plt.suptitle("Prediction on testing images")
    plt.show()

# Load filenames from the text file
filenames = [os.path.basename(line.split()[0]) for line in open(test_txt).readlines()]

plot_and_predict(model, test_images, test_labels, filenames, num_images=12)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
