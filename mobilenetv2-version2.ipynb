# %% [markdown]
# > Author: Bui Tran Gia Bao - 104177225

# %% [markdown]
# # **Importing libraries and defining data directories**

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.data import Dataset
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

data_dir = "/kaggle/input/bird-species"
train_images_dir = os.path.join(data_dir, "Train/")
test_images_dir = os.path.join(data_dir, "Test/")
train_txt = os.path.join(data_dir, "train.txt")
test_txt = os.path.join(data_dir, "test.txt")

# %% [markdown]
# # **Preprocessing data**

# %%
def load_data_from_txt(txt_file, images_dir):
    images, labels = [], []

    with open(txt_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            image_name, class_label = line.strip().split()
            image_path = os.path.join(images_dir, image_name)
            
            if os.path.exists(image_path):
                img = load_img(image_path, target_size=(224, 224))
                img_array = preprocess_input(img_to_array(img))
                
                images.append(img_array)
                labels.append(int(class_label))
            else:
                print(f"Error: Image {image_path} not found.")

    # Convert to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels


train_images, train_labels = load_data_from_txt(train_txt, train_images_dir)
test_images, test_labels = load_data_from_txt(test_txt, test_images_dir)

# Split the train data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.3, random_state=42
)

# Oversample the training dataset
ros = RandomOverSampler()
train_images_resampled, train_labels_resampled = ros.fit_resample(train_images.reshape((train_images.shape[0], -1)), train_labels)
train_images_resampled = train_images_resampled.reshape((-1, 224, 224, 3))

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

train_images_augmented = train_datagen.flow(train_images_resampled, train_labels_resampled, batch_size=32)


# Convert labels to one-hot encoding
train_labels = to_categorical(train_labels_resampled, num_classes=200)
val_labels = to_categorical(val_labels, num_classes=200)
test_labels = to_categorical(test_labels, num_classes=200)

# Create TensorFlow datasets
batch_size = 32
train_ds = Dataset.from_tensor_slices((train_images_resampled, train_labels)).shuffle(len(train_images_resampled)).batch(batch_size)
val_ds = Dataset.from_tensor_slices((val_images, val_labels)).batch(batch_size)
test_ds = Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

# Print the number of images per class to check for imbalance
unique_train, counts_train = np.unique(train_labels.argmax(axis=1), return_counts=True)
train_class_counts = dict(zip(unique_train, counts_train))
print('Training set class counts:', train_class_counts)

unique_test, counts_test = np.unique(test_labels.argmax(axis=1), return_counts=True)
test_class_counts = dict(zip(unique_test, counts_test))
print('Test set class counts:', test_class_counts)
# Out:
# Training set class counts: {0: 25, 1: 25, 2: 25, 3: 25, 4: 25, 5: 25, 6: 25, 7: 25, 8: 25, 9: 25, 10: 25, 11: 25, 12: 25, 13: 25, 14: 25, 15: 25, 16: 25, 17: 25, 18: 25, 19: 25, 20: 25, 21: 25, 22: 25, 23: 25, 24: 25, 25: 25, 26: 25, 27: 25, 28: 25, 29: 25, 30: 25, 31: 25, 32: 25, 33: 25, 34: 25, 35: 25, 36: 25, 37: 25, 38: 25, 39: 25, 40: 25, 41: 25, 42: 25, 43: 25, 44: 25, 45: 25, 46: 25, 47: 25, 48: 25, 49: 25, 50: 25, 51: 25, 52: 25, 53: 25, 54: 25, 55: 25, 56: 25, 57: 25, 58: 25, 59: 25, 60: 25, 61: 25, 62: 25, 63: 25, 64: 25, 65: 25, 66: 25, 67: 25, 68: 25, 69: 25, 70: 25, 71: 25, 72: 25, 73: 25, 74: 25, 75: 25, 76: 25, 77: 25, 78: 25, 79: 25, 80: 25, 81: 25, 82: 25, 83: 25, 84: 25, 85: 25, 86: 25, 87: 25, 88: 25, 89: 25, 90: 25, 91: 25, 92: 25, 93: 25, 94: 25, 95: 25, 96: 25, 97: 25, 98: 25, 99: 25, 100: 25, 101: 25, 102: 25, 103: 25, 104: 25, 105: 25, 106: 25, 107: 25, 108: 25, 109: 25, 110: 25, 111: 25, 112: 25, 113: 25, 114: 25, 115: 25, 116: 25, 117: 25, 118: 25, 119: 25, 120: 25, 121: 25, 122: 25, 123: 25, 124: 25, 125: 25, 126: 25, 127: 25, 128: 25, 129: 25, 130: 25, 131: 25, 132: 25, 133: 25, 134: 25, 135: 25, 136: 25, 137: 25, 138: 25, 139: 25, 140: 25, 141: 25, 142: 25, 143: 25, 144: 25, 145: 25, 146: 25, 147: 25, 148: 25, 149: 25, 150: 25, 151: 25, 152: 25, 153: 25, 154: 25, 155: 25, 156: 25, 157: 25, 158: 25, 159: 25, 160: 25, 161: 25, 162: 25, 163: 25, 164: 25, 165: 25, 166: 25, 167: 25, 168: 25, 169: 25, 170: 25, 171: 25, 172: 25, 173: 25, 174: 25, 175: 25, 176: 25, 177: 25, 178: 25, 179: 25, 180: 25, 181: 25, 182: 25, 183: 25, 184: 25, 185: 25, 186: 25, 187: 25, 188: 25, 189: 25, 190: 25, 191: 25, 192: 25, 193: 25, 194: 25, 195: 25, 196: 25, 197: 25, 198: 25, 199: 25}
# Test set class counts: {0: 7, 1: 5, 2: 5, 3: 7, 4: 5, 5: 6, 6: 7, 7: 6, 8: 5, 9: 5, 10: 5, 11: 6, 12: 5, 13: 7, 14: 6, 15: 6, 16: 5, 17: 4, 18: 7, 19: 7, 20: 6, 21: 4, 22: 5, 23: 4, 24: 6, 25: 5, 26: 6, 27: 7, 28: 5, 29: 6, 30: 7, 31: 6, 32: 7, 33: 5, 34: 6, 35: 8, 36: 7, 37: 7, 38: 6, 39: 6, 40: 7, 41: 5, 42: 7, 43: 4, 44: 6, 45: 7, 46: 5, 47: 7, 48: 7, 49: 7, 50: 6, 51: 6, 52: 7, 53: 6, 54: 5, 55: 4, 56: 4, 57: 5, 58: 5, 59: 7, 60: 5, 61: 5, 62: 4, 63: 5, 64: 6, 65: 6, 66: 5, 67: 5, 68: 7, 69: 6, 70: 6, 71: 6, 72: 7, 73: 7, 74: 7, 75: 5, 76: 7, 77: 7, 78: 6, 79: 5, 80: 7, 81: 7, 82: 7, 83: 4, 84: 6, 85: 7, 86: 5, 87: 6, 88: 7, 89: 6, 90: 6, 91: 6, 92: 7, 93: 7, 94: 5, 95: 7, 96: 7, 97: 6, 98: 6, 99: 6, 100: 5, 101: 7, 102: 5, 103: 6, 104: 4, 105: 6, 106: 5, 107: 6, 108: 6, 109: 5, 110: 7, 111: 6, 112: 7, 113: 7, 114: 7, 115: 6, 116: 7, 117: 6, 118: 6, 119: 7, 120: 7, 121: 5, 122: 7, 123: 7, 124: 7, 125: 6, 126: 7, 127: 5, 128: 8, 129: 4, 130: 8, 131: 5, 132: 7, 133: 7, 134: 5, 135: 5, 136: 6, 137: 7, 138: 5, 139: 4, 140: 7, 141: 4, 142: 8, 143: 7, 144: 5, 145: 5, 146: 5, 147: 7, 148: 6, 149: 5, 150: 5, 151: 7, 152: 7, 153: 7, 154: 7, 155: 7, 156: 6, 157: 6, 158: 7, 159: 4, 160: 7, 161: 7, 162: 7, 163: 5, 164: 6, 165: 7, 166: 5, 167: 6, 168: 5, 169: 7, 170: 4, 171: 6, 172: 6, 173: 6, 174: 6, 175: 7, 176: 7, 177: 5, 178: 6, 179: 7, 180: 6, 181: 4, 182: 7, 183: 6, 184: 7, 185: 7, 186: 6, 187: 8, 188: 7, 189: 4, 190: 6, 191: 8, 192: 7, 193: 5, 194: 7, 195: 5, 196: 6, 197: 5, 198: 7, 199: 5}

# %% [markdown]
# # **Training the model**

# %%
NUM_CLASSES = 200
IMAGE_RESIZE = 224
POOLING_AVERAGE = 'avg'
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'
LOSS_METRICS = ['accuracy']
NUM_EPOCHS = 100
LEARNING_RATE = 0.0001
best_model = '/kaggle/working/bird-model.keras'
checkpoint = '/kaggle/working/checkpoint_model_epoch_{epoch:02d}.keras'
callbacks = [
    ModelCheckpoint(best_model, verbose=1, save_best_only=True, monitor='val_accuracy'),
    ModelCheckpoint(checkpoint, verbose=1, save_weights_only=False, save_freq=5 * len(train_ds), save_best_only=False),
    ReduceLROnPlateau(monitor='val_accuracy', patience=2, factor=0.2, verbose=1, min_lr=1e-9),
    EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, restore_best_weights=True)
]

# %%
# Build the model.
model = Sequential()

# Using MobileNetV2 as feature extractor
mobilenet= MobileNetV2(include_top=False,
                 input_shape=(IMAGE_RESIZE, IMAGE_RESIZE, 3),
                 pooling=POOLING_AVERAGE, weights='imagenet')

for layer in mobilenet.layers[:-10]:
    layer.trainable = False
for layer in mobilenet.layers[-10:]:
    layer.trainable = True

model.add(mobilenet)
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation=DENSE_LAYER_ACTIVATION, kernel_regularizer=l2(0.01)))
model.build((None, IMAGE_RESIZE, IMAGE_RESIZE, 3))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 200)            │        13,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,443,208 (9.32 MB)
#  Trainable params: 915,784 (3.49 MB)
#  Non-trainable params: 1,527,424 (5.83 MB)

# %%
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss=OBJECTIVE_FUNCTION, metrics=LOSS_METRICS)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729408374.086622      64 service.cc:145] XLA service 0x79c6980018a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729408374.086680      64 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   7/157 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.0000e+00 - loss: 9.6000
# I0000 00:00:1729408383.049724      64 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.0044 - loss: 9.3928
# Epoch 1: val_accuracy improved from -inf to 0.01242, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 36s 117ms/step - accuracy: 0.0044 - loss: 9.3918 - val_accuracy: 0.0124 - val_loss: 8.9323 - learning_rate: 1.0000e-04
# Epoch 2/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0100 - loss: 8.7938
# Epoch 2: val_accuracy improved from 0.01242 to 0.02622, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.0101 - loss: 8.7914 - val_accuracy: 0.0262 - val_loss: 8.4120 - learning_rate: 1.0000e-04
# Epoch 3/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0136 - loss: 8.2984
# Epoch 3: val_accuracy improved from 0.02622 to 0.04762, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.0137 - loss: 8.2962 - val_accuracy: 0.0476 - val_loss: 7.9356 - learning_rate: 1.0000e-04
# Epoch 4/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0297 - loss: 7.8210
# Epoch 4: val_accuracy improved from 0.04762 to 0.05866, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.0297 - loss: 7.8193 - val_accuracy: 0.0587 - val_loss: 7.5196 - learning_rate: 1.0000e-04
# Epoch 5/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0412 - loss: 7.4393
# Epoch 5: saving model to /kaggle/working/checkpoint_model_epoch_05.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0412 - loss: 7.4382
# Epoch 5: val_accuracy improved from 0.05866 to 0.08144, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.0412 - loss: 7.4377 - val_accuracy: 0.0814 - val_loss: 7.1352 - learning_rate: 1.0000e-04
# Epoch 6/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0554 - loss: 7.0740
# Epoch 6: val_accuracy improved from 0.08144 to 0.10145, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.0554 - loss: 7.0724 - val_accuracy: 0.1014 - val_loss: 6.7843 - learning_rate: 1.0000e-04
# Epoch 7/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0659 - loss: 6.7637
# Epoch 7: val_accuracy improved from 0.10145 to 0.12284, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.0660 - loss: 6.7628 - val_accuracy: 0.1228 - val_loss: 6.4787 - learning_rate: 1.0000e-04
# Epoch 8/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0693 - loss: 6.5451
# Epoch 8: val_accuracy improved from 0.12284 to 0.14355, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.0693 - loss: 6.5438 - val_accuracy: 0.1435 - val_loss: 6.2068 - learning_rate: 1.0000e-04
# Epoch 9/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0797 - loss: 6.2704
# Epoch 9: val_accuracy improved from 0.14355 to 0.16425, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.0797 - loss: 6.2695 - val_accuracy: 0.1643 - val_loss: 5.9349 - learning_rate: 1.0000e-04
# Epoch 10/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1022 - loss: 6.0382
# Epoch 10: saving model to /kaggle/working/checkpoint_model_epoch_10.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.1022 - loss: 6.0378
# Epoch 10: val_accuracy improved from 0.16425 to 0.19945, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.1022 - loss: 6.0376 - val_accuracy: 0.1994 - val_loss: 5.7174 - learning_rate: 1.0000e-04
# Epoch 11/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1110 - loss: 5.8260
# Epoch 11: val_accuracy improved from 0.19945 to 0.21670, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.1111 - loss: 5.8254 - val_accuracy: 0.2167 - val_loss: 5.5388 - learning_rate: 1.0000e-04
# Epoch 12/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1245 - loss: 5.6787
# Epoch 12: val_accuracy improved from 0.21670 to 0.22843, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.1245 - loss: 5.6779 - val_accuracy: 0.2284 - val_loss: 5.3393 - learning_rate: 1.0000e-04
# Epoch 13/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1429 - loss: 5.4791
# Epoch 13: val_accuracy improved from 0.22843 to 0.25328, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.1428 - loss: 5.4788 - val_accuracy: 0.2533 - val_loss: 5.1817 - learning_rate: 1.0000e-04
# Epoch 14/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1417 - loss: 5.3737
# Epoch 14: val_accuracy improved from 0.25328 to 0.25742, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.1417 - loss: 5.3737 - val_accuracy: 0.2574 - val_loss: 5.0548 - learning_rate: 1.0000e-04
# Epoch 15/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1453 - loss: 5.2609
# Epoch 15: saving model to /kaggle/working/checkpoint_model_epoch_15.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1453 - loss: 5.2606
# Epoch 15: val_accuracy improved from 0.25742 to 0.27122, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.1453 - loss: 5.2604 - val_accuracy: 0.2712 - val_loss: 4.8924 - learning_rate: 1.0000e-04
# Epoch 16/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1490 - loss: 5.1255
# Epoch 16: val_accuracy improved from 0.27122 to 0.27467, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.1490 - loss: 5.1257 - val_accuracy: 0.2747 - val_loss: 4.7629 - learning_rate: 1.0000e-04
# Epoch 17/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.1560 - loss: 5.0189
# Epoch 17: val_accuracy improved from 0.27467 to 0.27674, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.1560 - loss: 5.0187 - val_accuracy: 0.2767 - val_loss: 4.6888 - learning_rate: 1.0000e-04
# Epoch 18/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1670 - loss: 4.9099
# Epoch 18: val_accuracy improved from 0.27674 to 0.30021, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.1669 - loss: 4.9098 - val_accuracy: 0.3002 - val_loss: 4.5983 - learning_rate: 1.0000e-04
# Epoch 19/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1650 - loss: 4.8525
# Epoch 19: val_accuracy did not improve from 0.30021
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.1651 - loss: 4.8520 - val_accuracy: 0.2988 - val_loss: 4.5141 - learning_rate: 1.0000e-04
# Epoch 20/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1868 - loss: 4.7254
# Epoch 20: saving model to /kaggle/working/checkpoint_model_epoch_20.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1868 - loss: 4.7253
# Epoch 20: val_accuracy improved from 0.30021 to 0.31056, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.1868 - loss: 4.7253 - val_accuracy: 0.3106 - val_loss: 4.4356 - learning_rate: 1.0000e-04
# Epoch 21/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1899 - loss: 4.6474
# Epoch 21: val_accuracy did not improve from 0.31056
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.1900 - loss: 4.6473 - val_accuracy: 0.3037 - val_loss: 4.3704 - learning_rate: 1.0000e-04
# Epoch 22/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2087 - loss: 4.5648
# Epoch 22: val_accuracy improved from 0.31056 to 0.31263, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2085 - loss: 4.5648 - val_accuracy: 0.3126 - val_loss: 4.3156 - learning_rate: 1.0000e-04
# Epoch 23/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2033 - loss: 4.5330
# Epoch 23: val_accuracy did not improve from 0.31263
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2033 - loss: 4.5328 - val_accuracy: 0.2947 - val_loss: 4.3022 - learning_rate: 1.0000e-04
# Epoch 24/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2041 - loss: 4.5042
# Epoch 24: val_accuracy improved from 0.31263 to 0.31401, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2042 - loss: 4.5036 - val_accuracy: 0.3140 - val_loss: 4.2336 - learning_rate: 1.0000e-04
# Epoch 25/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2263 - loss: 4.3905
# Epoch 25: saving model to /kaggle/working/checkpoint_model_epoch_25.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2263 - loss: 4.3901
# Epoch 25: val_accuracy improved from 0.31401 to 0.32436, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.2263 - loss: 4.3899 - val_accuracy: 0.3244 - val_loss: 4.1664 - learning_rate: 1.0000e-04
# Epoch 26/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2270 - loss: 4.3401
# Epoch 26: val_accuracy improved from 0.32436 to 0.32850, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2269 - loss: 4.3401 - val_accuracy: 0.3285 - val_loss: 4.1349 - learning_rate: 1.0000e-04
# Epoch 27/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2300 - loss: 4.2417
# Epoch 27: val_accuracy improved from 0.32850 to 0.33954, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2300 - loss: 4.2423 - val_accuracy: 0.3395 - val_loss: 4.0295 - learning_rate: 1.0000e-04
# Epoch 28/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2317 - loss: 4.2288
# Epoch 28: val_accuracy improved from 0.33954 to 0.35128, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2318 - loss: 4.2286 - val_accuracy: 0.3513 - val_loss: 3.9792 - learning_rate: 1.0000e-04
# Epoch 29/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2486 - loss: 4.1856
# Epoch 29: val_accuracy improved from 0.35128 to 0.35611, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2485 - loss: 4.1854 - val_accuracy: 0.3561 - val_loss: 3.9635 - learning_rate: 1.0000e-04
# Epoch 30/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2609 - loss: 4.0798
# Epoch 30: saving model to /kaggle/working/checkpoint_model_epoch_30.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2609 - loss: 4.0802
# Epoch 30: val_accuracy improved from 0.35611 to 0.36301, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.2609 - loss: 4.0804 - val_accuracy: 0.3630 - val_loss: 3.9016 - learning_rate: 1.0000e-04
# Epoch 31/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2759 - loss: 4.0538
# Epoch 31: val_accuracy did not improve from 0.36301
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2758 - loss: 4.0541 - val_accuracy: 0.3596 - val_loss: 3.8806 - learning_rate: 1.0000e-04
# Epoch 32/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2591 - loss: 4.0459
# Epoch 32: val_accuracy did not improve from 0.36301
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.2593 - loss: 4.0454 - val_accuracy: 0.3520 - val_loss: 3.8991 - learning_rate: 1.0000e-04
# Epoch 33/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2810 - loss: 3.9698
# Epoch 33: val_accuracy improved from 0.36301 to 0.36439, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2810 - loss: 3.9696 - val_accuracy: 0.3644 - val_loss: 3.8585 - learning_rate: 2.0000e-05
# Epoch 34/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2806 - loss: 3.9457
# Epoch 34: val_accuracy improved from 0.36439 to 0.37267, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2806 - loss: 3.9458 - val_accuracy: 0.3727 - val_loss: 3.8500 - learning_rate: 2.0000e-05
# Epoch 35/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2815 - loss: 3.9022
# Epoch 35: saving model to /kaggle/working/checkpoint_model_epoch_35.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2814 - loss: 3.9025
# Epoch 35: val_accuracy improved from 0.37267 to 0.37405, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.2814 - loss: 3.9027 - val_accuracy: 0.3741 - val_loss: 3.8437 - learning_rate: 2.0000e-05
# Epoch 36/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2786 - loss: 3.9187
# Epoch 36: val_accuracy did not improve from 0.37405
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2787 - loss: 3.9186 - val_accuracy: 0.3720 - val_loss: 3.8256 - learning_rate: 2.0000e-05
# Epoch 37/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2769 - loss: 3.9194
# Epoch 37: val_accuracy did not improve from 0.37405
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.2770 - loss: 3.9193 - val_accuracy: 0.3734 - val_loss: 3.8195 - learning_rate: 2.0000e-05
# Epoch 38/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2932 - loss: 3.8601
# Epoch 38: val_accuracy did not improve from 0.37405
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2933 - loss: 3.8600 - val_accuracy: 0.3734 - val_loss: 3.8169 - learning_rate: 4.0000e-06
# Epoch 39/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2875 - loss: 3.9189
# Epoch 39: val_accuracy improved from 0.37405 to 0.37888, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2875 - loss: 3.9190 - val_accuracy: 0.3789 - val_loss: 3.8162 - learning_rate: 4.0000e-06
# Epoch 40/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2976 - loss: 3.8562
# Epoch 40: saving model to /kaggle/working/checkpoint_model_epoch_40.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2975 - loss: 3.8565
# Epoch 40: val_accuracy did not improve from 0.37888
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.2974 - loss: 3.8567 - val_accuracy: 0.3775 - val_loss: 3.8127 - learning_rate: 4.0000e-06
# Epoch 41/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2865 - loss: 3.9193
# Epoch 41: val_accuracy did not improve from 0.37888
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2865 - loss: 3.9190 - val_accuracy: 0.3734 - val_loss: 3.8095 - learning_rate: 4.0000e-06
# Epoch 42/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3031 - loss: 3.8421
# Epoch 42: val_accuracy did not improve from 0.37888
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.3029 - loss: 3.8424 - val_accuracy: 0.3741 - val_loss: 3.8094 - learning_rate: 8.0000e-07
# Epoch 43/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2759 - loss: 3.9011
# Epoch 43: val_accuracy did not improve from 0.37888
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.2761 - loss: 3.9009 - val_accuracy: 0.3761 - val_loss: 3.8093 - learning_rate: 8.0000e-07
# Epoch 44/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2867 - loss: 3.8981
# Epoch 44: val_accuracy did not improve from 0.37888
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2867 - loss: 3.8979 - val_accuracy: 0.3768 - val_loss: 3.8095 - learning_rate: 1.6000e-07
# Epoch 45/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2954 - loss: 3.8876
# Epoch 45: saving model to /kaggle/working/checkpoint_model_epoch_45.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2953 - loss: 3.8876
# Epoch 45: val_accuracy did not improve from 0.37888
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.2952 - loss: 3.8876 - val_accuracy: 0.3768 - val_loss: 3.8100 - learning_rate: 1.6000e-07
# Epoch 46/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2822 - loss: 3.8991
# Epoch 46: val_accuracy did not improve from 0.37888
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2822 - loss: 3.8989 - val_accuracy: 0.3768 - val_loss: 3.8102 - learning_rate: 3.2000e-08
# Epoch 47/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2982 - loss: 3.8674
# Epoch 47: val_accuracy did not improve from 0.37888
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2984 - loss: 3.8673 - val_accuracy: 0.3761 - val_loss: 3.8107 - learning_rate: 3.2000e-08
# Epoch 48/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2986 - loss: 3.8661
# Epoch 48: val_accuracy did not improve from 0.37888
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2986 - loss: 3.8661 - val_accuracy: 0.3761 - val_loss: 3.8110 - learning_rate: 6.4000e-09
# Epoch 49/100
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2920 - loss: 3.8893
# Epoch 49: val_accuracy did not improve from 0.37888
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.2919 - loss: 3.8894 - val_accuracy: 0.3761 - val_loss: 3.8113 - learning_rate: 6.4000e-09
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 39.

# %%
best_val_acc=max(history.history['val_accuracy'])
print(f"Best validation accuracy: {best_val_acc * 100:.2f}%")
# Out:
# Best validation accuracy: 37.89%

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Plot accuracy
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_ylim([0, 1])
axs[0].set_title('Training and Validation Accuracy')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].legend()
axs[0].grid(True)

# Plot loss
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Training and Validation Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Evaluation**

# %%
# Evaluate on test data
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Accuracy (Top-1 Accuracy): {test_accuracy * 100:.2f}%")

# Predict on the entire test dataset
y_pred = np.argmax(model.predict(test_ds), axis=-1)
y_true = np.concatenate([np.argmax(y, axis=-1) for _, y in test_ds], axis=0)

cm = confusion_matrix(y_true, y_pred)

# Calculate accuracy for each class
per_class_accuracy = cm.diagonal() / cm.sum(axis=1)

average_accuracy_per_class = np.mean(per_class_accuracy)
print(f"Average Accuracy per Class: {average_accuracy_per_class * 100:.2f}%")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.4154 - loss: 3.7136
# Test Accuracy (Top-1 Accuracy): 36.63%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step
# Average Accuracy per Class: 36.53%

# %%
def plot_and_predict(model, test_images, test_labels, filenames, num_images):
    plt.figure(figsize=(15, 10))
    rows = num_images // 6 + (num_images % 6 > 0)
    for i in range(num_images):
        idx = random.randint(0, len(test_images) - 1)
        img = test_images[idx]
        filename = filenames[idx]
        true_label = np.argmax(test_labels[idx])

        prediction = model.predict(np.expand_dims(img, axis=0))
        predicted_label = np.argmax(prediction)
        
        if true_label == predicted_label:
            color = 'green'
        else:
            color = 'red'

        plt.subplot(rows, 6, i + 1)
        plt.imshow((img + 1) / 2)
        plt.title(f"Filename: {filename}\nTrue: {true_label}, Prediction: {predicted_label}", color=color)
        plt.axis('off')

    plt.tight_layout(pad=0, h_pad=0, w_pad=1.0)
    plt.suptitle("Prediction on testing images")
    plt.show()

# Load filenames from the text file
filenames = [os.path.basename(line.split()[0]) for line in open(test_txt).readlines()]

plot_and_predict(model, test_images, test_labels, filenames, num_images=12)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
