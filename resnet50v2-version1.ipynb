# %% [markdown]
# > Author: Bui Tran Gia Bao - 104177225

# %% [markdown]
# # **Importing libraries and defining data directories**

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.data import Dataset
from tensorflow.keras.models import load_model
from tensorflow.keras.regularizers import l2

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

data_dir = "/kaggle/input/d/solar11781/bird-species/"
train_images_dir = os.path.join(data_dir, "Train/")
test_images_dir = os.path.join(data_dir, "Test/")
train_txt = os.path.join(data_dir, "train.txt")
test_txt = os.path.join(data_dir, "test.txt")

# %% [markdown]
# # **Preprocessing data**

# %%
def load_data_from_txt(txt_file, images_dir):
    images, labels = [], []

    with open(txt_file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            image_name, class_label = line.strip().split()
            image_path = os.path.join(images_dir, image_name)
            
            if os.path.exists(image_path):
                img = load_img(image_path, target_size=(224, 224))
                img_array = preprocess_input(img_to_array(img))
                
                images.append(img_array)
                labels.append(int(class_label))
            else:
                print(f"Error: Image {image_path} not found.")

    # Convert to NumPy arrays
    images = np.array(images)
    labels = np.array(labels)
    
    return images, labels


train_images, train_labels = load_data_from_txt(train_txt, train_images_dir)
test_images, test_labels = load_data_from_txt(test_txt, test_images_dir)

# Split the train data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.3, random_state=42
)

# Oversample the training dataset
ros = RandomOverSampler()
train_images_resampled, train_labels_resampled = ros.fit_resample(train_images.reshape((train_images.shape[0], -1)), train_labels)
train_images_resampled = train_images_resampled.reshape((-1, 224, 224, 3))

# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

train_images_augmented = train_datagen.flow(train_images_resampled, train_labels_resampled, batch_size=32)


# Convert labels to one-hot encoding
train_labels = to_categorical(train_labels_resampled, num_classes=200)
val_labels = to_categorical(val_labels, num_classes=200)
test_labels = to_categorical(test_labels, num_classes=200)

# Create TensorFlow datasets
batch_size = 32
train_ds = Dataset.from_tensor_slices((train_images_resampled, train_labels)).shuffle(len(train_images_resampled)).batch(batch_size)
val_ds = Dataset.from_tensor_slices((val_images, val_labels)).batch(batch_size)
test_ds = Dataset.from_tensor_slices((test_images, test_labels)).batch(batch_size)

# Print the number of images per class to check for imbalance
unique_train, counts_train = np.unique(train_labels.argmax(axis=1), return_counts=True)
train_class_counts = dict(zip(unique_train, counts_train))
print('Training set class counts:', train_class_counts)

unique_test, counts_test = np.unique(test_labels.argmax(axis=1), return_counts=True)
test_class_counts = dict(zip(unique_test, counts_test))
print('Test set class counts:', test_class_counts)
# Out:
# Training set class counts: {0: 25, 1: 25, 2: 25, 3: 25, 4: 25, 5: 25, 6: 25, 7: 25, 8: 25, 9: 25, 10: 25, 11: 25, 12: 25, 13: 25, 14: 25, 15: 25, 16: 25, 17: 25, 18: 25, 19: 25, 20: 25, 21: 25, 22: 25, 23: 25, 24: 25, 25: 25, 26: 25, 27: 25, 28: 25, 29: 25, 30: 25, 31: 25, 32: 25, 33: 25, 34: 25, 35: 25, 36: 25, 37: 25, 38: 25, 39: 25, 40: 25, 41: 25, 42: 25, 43: 25, 44: 25, 45: 25, 46: 25, 47: 25, 48: 25, 49: 25, 50: 25, 51: 25, 52: 25, 53: 25, 54: 25, 55: 25, 56: 25, 57: 25, 58: 25, 59: 25, 60: 25, 61: 25, 62: 25, 63: 25, 64: 25, 65: 25, 66: 25, 67: 25, 68: 25, 69: 25, 70: 25, 71: 25, 72: 25, 73: 25, 74: 25, 75: 25, 76: 25, 77: 25, 78: 25, 79: 25, 80: 25, 81: 25, 82: 25, 83: 25, 84: 25, 85: 25, 86: 25, 87: 25, 88: 25, 89: 25, 90: 25, 91: 25, 92: 25, 93: 25, 94: 25, 95: 25, 96: 25, 97: 25, 98: 25, 99: 25, 100: 25, 101: 25, 102: 25, 103: 25, 104: 25, 105: 25, 106: 25, 107: 25, 108: 25, 109: 25, 110: 25, 111: 25, 112: 25, 113: 25, 114: 25, 115: 25, 116: 25, 117: 25, 118: 25, 119: 25, 120: 25, 121: 25, 122: 25, 123: 25, 124: 25, 125: 25, 126: 25, 127: 25, 128: 25, 129: 25, 130: 25, 131: 25, 132: 25, 133: 25, 134: 25, 135: 25, 136: 25, 137: 25, 138: 25, 139: 25, 140: 25, 141: 25, 142: 25, 143: 25, 144: 25, 145: 25, 146: 25, 147: 25, 148: 25, 149: 25, 150: 25, 151: 25, 152: 25, 153: 25, 154: 25, 155: 25, 156: 25, 157: 25, 158: 25, 159: 25, 160: 25, 161: 25, 162: 25, 163: 25, 164: 25, 165: 25, 166: 25, 167: 25, 168: 25, 169: 25, 170: 25, 171: 25, 172: 25, 173: 25, 174: 25, 175: 25, 176: 25, 177: 25, 178: 25, 179: 25, 180: 25, 181: 25, 182: 25, 183: 25, 184: 25, 185: 25, 186: 25, 187: 25, 188: 25, 189: 25, 190: 25, 191: 25, 192: 25, 193: 25, 194: 25, 195: 25, 196: 25, 197: 25, 198: 25, 199: 25}
# Test set class counts: {0: 7, 1: 5, 2: 5, 3: 7, 4: 5, 5: 6, 6: 7, 7: 6, 8: 5, 9: 5, 10: 5, 11: 6, 12: 5, 13: 7, 14: 6, 15: 6, 16: 5, 17: 4, 18: 7, 19: 7, 20: 6, 21: 4, 22: 5, 23: 4, 24: 6, 25: 5, 26: 6, 27: 7, 28: 5, 29: 6, 30: 7, 31: 6, 32: 7, 33: 5, 34: 6, 35: 8, 36: 7, 37: 7, 38: 6, 39: 6, 40: 7, 41: 5, 42: 7, 43: 4, 44: 6, 45: 7, 46: 5, 47: 7, 48: 7, 49: 7, 50: 6, 51: 6, 52: 7, 53: 6, 54: 5, 55: 4, 56: 4, 57: 5, 58: 5, 59: 7, 60: 5, 61: 5, 62: 4, 63: 5, 64: 6, 65: 6, 66: 5, 67: 5, 68: 7, 69: 6, 70: 6, 71: 6, 72: 7, 73: 7, 74: 7, 75: 5, 76: 7, 77: 7, 78: 6, 79: 5, 80: 7, 81: 7, 82: 7, 83: 4, 84: 6, 85: 7, 86: 5, 87: 6, 88: 7, 89: 6, 90: 6, 91: 6, 92: 7, 93: 7, 94: 5, 95: 7, 96: 7, 97: 6, 98: 6, 99: 6, 100: 5, 101: 7, 102: 5, 103: 6, 104: 4, 105: 6, 106: 5, 107: 6, 108: 6, 109: 5, 110: 7, 111: 6, 112: 7, 113: 7, 114: 7, 115: 6, 116: 7, 117: 6, 118: 6, 119: 7, 120: 7, 121: 5, 122: 7, 123: 7, 124: 7, 125: 6, 126: 7, 127: 5, 128: 8, 129: 4, 130: 8, 131: 5, 132: 7, 133: 7, 134: 5, 135: 5, 136: 6, 137: 7, 138: 5, 139: 4, 140: 7, 141: 4, 142: 8, 143: 7, 144: 5, 145: 5, 146: 5, 147: 7, 148: 6, 149: 5, 150: 5, 151: 7, 152: 7, 153: 7, 154: 7, 155: 7, 156: 6, 157: 6, 158: 7, 159: 4, 160: 7, 161: 7, 162: 7, 163: 5, 164: 6, 165: 7, 166: 5, 167: 6, 168: 5, 169: 7, 170: 4, 171: 6, 172: 6, 173: 6, 174: 6, 175: 7, 176: 7, 177: 5, 178: 6, 179: 7, 180: 6, 181: 4, 182: 7, 183: 6, 184: 7, 185: 7, 186: 6, 187: 8, 188: 7, 189: 4, 190: 6, 191: 8, 192: 7, 193: 5, 194: 7, 195: 5, 196: 6, 197: 5, 198: 7, 199: 5}

# %% [markdown]
# # **Training the model**

# %%
NUM_CLASSES = 200
IMAGE_RESIZE = 224
POOLING_AVERAGE = 'avg'
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'
LOSS_METRICS = ['accuracy']
NUM_EPOCHS = 50
LEARNING_RATE = 0.001
best_model = '/kaggle/working/bird-model.keras'
checkpoint = '/kaggle/working/checkpoint_model_epoch_{epoch:02d}.keras'
callbacks = [
    ModelCheckpoint(best_model, verbose=1, save_best_only=True, monitor='val_accuracy'),
    ModelCheckpoint(checkpoint, verbose=1, save_weights_only=False, save_freq=5 * len(train_ds), save_best_only=False),
    ReduceLROnPlateau(monitor='val_accuracy', patience=2, factor=0.3, verbose=1, min_lr=1e-9),
    EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, restore_best_weights=True)
]

# %%
# Build the model.
model = Sequential()

# Using ResNet50 as feature extractor
resnet= ResNet50V2(include_top=False,
                 input_shape=(IMAGE_RESIZE, IMAGE_RESIZE, 3),
                 pooling=POOLING_AVERAGE, weights='imagenet')

for layer in resnet.layers[:-10]:
    layer.trainable = False
for layer in resnet.layers[-10:]:
    layer.trainable = True

model.add(resnet)
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation=DENSE_LAYER_ACTIVATION, kernel_regularizer=l2(0.01)))
model.build((None, IMAGE_RESIZE, IMAGE_RESIZE, 3))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50v2 (Functional)         │ (None, 2048)           │    23,564,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 200)            │        13,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,848,328 (90.97 MB)
#  Trainable params: 3,698,568 (14.11 MB)
#  Non-trainable params: 20,149,760 (76.87 MB)

# %%
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE), loss=OBJECTIVE_FUNCTION, metrics=LOSS_METRICS)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729398990.699857      63 service.cc:145] XLA service 0x7a2084045360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729398990.699901      63 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   2/157 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.0469 - loss: 9.5629
# I0000 00:00:1729399000.337162      63 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.0092 - loss: 7.8913
# Epoch 1: val_accuracy improved from -inf to 0.01311, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 154ms/step - accuracy: 0.0092 - loss: 7.8850 - val_accuracy: 0.0131 - val_loss: 5.5644 - learning_rate: 0.0010
# Epoch 2/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0213 - loss: 5.4878
# Epoch 2: val_accuracy improved from 0.01311 to 0.05038, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0213 - loss: 5.4860 - val_accuracy: 0.0504 - val_loss: 4.7564 - learning_rate: 0.0010
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0329 - loss: 4.9233
# Epoch 3: val_accuracy improved from 0.05038 to 0.05866, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.0329 - loss: 4.9228 - val_accuracy: 0.0587 - val_loss: 4.4406 - learning_rate: 0.0010
# Epoch 4/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0400 - loss: 4.6450
# Epoch 4: val_accuracy improved from 0.05866 to 0.09041, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.0401 - loss: 4.6441 - val_accuracy: 0.0904 - val_loss: 4.2308 - learning_rate: 0.0010
# Epoch 5/50
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0635 - loss: 4.3394
# Epoch 5: saving model to /kaggle/working/checkpoint_model_epoch_05.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0635 - loss: 4.3393
# Epoch 5: val_accuracy improved from 0.09041 to 0.09524, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.0636 - loss: 4.3392 - val_accuracy: 0.0952 - val_loss: 4.0771 - learning_rate: 0.0010
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0835 - loss: 4.0907
# Epoch 6: val_accuracy did not improve from 0.09524
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.0835 - loss: 4.0908 - val_accuracy: 0.0876 - val_loss: 4.1690 - learning_rate: 0.0010
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1024 - loss: 3.9949
# Epoch 7: val_accuracy improved from 0.09524 to 0.12353, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.1024 - loss: 3.9947 - val_accuracy: 0.1235 - val_loss: 3.9841 - learning_rate: 0.0010
# Epoch 8/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1211 - loss: 3.8144
# Epoch 8: val_accuracy improved from 0.12353 to 0.14217, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.1211 - loss: 3.8142 - val_accuracy: 0.1422 - val_loss: 3.9828 - learning_rate: 0.0010
# Epoch 9/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1316 - loss: 3.7381
# Epoch 9: val_accuracy did not improve from 0.14217
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.1316 - loss: 3.7377 - val_accuracy: 0.1408 - val_loss: 3.9508 - learning_rate: 0.0010
# Epoch 10/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1497 - loss: 3.5750
# Epoch 10: saving model to /kaggle/working/checkpoint_model_epoch_10.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.1497 - loss: 3.5751
# Epoch 10: val_accuracy improved from 0.14217 to 0.17253, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.1497 - loss: 3.5751 - val_accuracy: 0.1725 - val_loss: 3.8888 - learning_rate: 0.0010
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1702 - loss: 3.5010
# Epoch 11: val_accuracy did not improve from 0.17253
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.1702 - loss: 3.5009 - val_accuracy: 0.1684 - val_loss: 3.8599 - learning_rate: 0.0010
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1881 - loss: 3.4304
# Epoch 12: val_accuracy did not improve from 0.17253
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.1881 - loss: 3.4302 - val_accuracy: 0.1636 - val_loss: 3.8905 - learning_rate: 0.0010
# Epoch 13/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2242 - loss: 3.2092
# Epoch 13: val_accuracy improved from 0.17253 to 0.21532, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2242 - loss: 3.2085 - val_accuracy: 0.2153 - val_loss: 3.7010 - learning_rate: 3.0000e-04
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2748 - loss: 3.0096
# Epoch 14: val_accuracy improved from 0.21532 to 0.22153, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2748 - loss: 3.0096 - val_accuracy: 0.2215 - val_loss: 3.7137 - learning_rate: 3.0000e-04
# Epoch 15/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2865 - loss: 2.9053
# Epoch 15: saving model to /kaggle/working/checkpoint_model_epoch_15.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2866 - loss: 2.9052
# Epoch 15: val_accuracy did not improve from 0.22153
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.2866 - loss: 2.9052 - val_accuracy: 0.2070 - val_loss: 3.7575 - learning_rate: 3.0000e-04
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2983 - loss: 2.8637
# Epoch 16: val_accuracy did not improve from 0.22153
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.2983 - loss: 2.8636 - val_accuracy: 0.2208 - val_loss: 3.7362 - learning_rate: 3.0000e-04
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3215 - loss: 2.7570
# Epoch 17: val_accuracy improved from 0.22153 to 0.22636, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3215 - loss: 2.7571 - val_accuracy: 0.2264 - val_loss: 3.7134 - learning_rate: 9.0000e-05
# Epoch 18/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3458 - loss: 2.7164
# Epoch 18: val_accuracy improved from 0.22636 to 0.23602, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3457 - loss: 2.7164 - val_accuracy: 0.2360 - val_loss: 3.7167 - learning_rate: 9.0000e-05
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3712 - loss: 2.6699
# Epoch 19: val_accuracy improved from 0.23602 to 0.24017, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3711 - loss: 2.6700 - val_accuracy: 0.2402 - val_loss: 3.7364 - learning_rate: 9.0000e-05
# Epoch 20/50
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3591 - loss: 2.6480
# Epoch 20: saving model to /kaggle/working/checkpoint_model_epoch_20.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3592 - loss: 2.6482
# Epoch 20: val_accuracy did not improve from 0.24017
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.3592 - loss: 2.6482 - val_accuracy: 0.2340 - val_loss: 3.7352 - learning_rate: 9.0000e-05
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3674 - loss: 2.6584
# Epoch 21: val_accuracy did not improve from 0.24017
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.3674 - loss: 2.6584 - val_accuracy: 0.2340 - val_loss: 3.7682 - learning_rate: 9.0000e-05
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3702 - loss: 2.6374
# Epoch 22: val_accuracy improved from 0.24017 to 0.24224, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3702 - loss: 2.6374 - val_accuracy: 0.2422 - val_loss: 3.7539 - learning_rate: 2.7000e-05
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4031 - loss: 2.6095
# Epoch 23: val_accuracy improved from 0.24224 to 0.24293, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.4030 - loss: 2.6095 - val_accuracy: 0.2429 - val_loss: 3.7659 - learning_rate: 2.7000e-05
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3886 - loss: 2.5811
# Epoch 24: val_accuracy did not improve from 0.24293
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.3886 - loss: 2.5812 - val_accuracy: 0.2422 - val_loss: 3.7618 - learning_rate: 2.7000e-05
# Epoch 25/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3940 - loss: 2.5625
# Epoch 25: saving model to /kaggle/working/checkpoint_model_epoch_25.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3940 - loss: 2.5626
# Epoch 25: val_accuracy did not improve from 0.24293
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.3939 - loss: 2.5627 - val_accuracy: 0.2402 - val_loss: 3.7672 - learning_rate: 2.7000e-05
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3896 - loss: 2.5770
# Epoch 26: val_accuracy did not improve from 0.24293
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.3896 - loss: 2.5770 - val_accuracy: 0.2388 - val_loss: 3.7633 - learning_rate: 8.1000e-06
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3883 - loss: 2.5663
# Epoch 27: val_accuracy improved from 0.24293 to 0.24431, saving model to /kaggle/working/bird-model.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3883 - loss: 2.5664 - val_accuracy: 0.2443 - val_loss: 3.7643 - learning_rate: 8.1000e-06
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3967 - loss: 2.6058
# Epoch 28: val_accuracy did not improve from 0.24431
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.3968 - loss: 2.6057 - val_accuracy: 0.2443 - val_loss: 3.7640 - learning_rate: 8.1000e-06
# Epoch 29/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3896 - loss: 2.5674
# Epoch 29: val_accuracy did not improve from 0.24431
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.3896 - loss: 2.5675 - val_accuracy: 0.2422 - val_loss: 3.7675 - learning_rate: 8.1000e-06
# Epoch 30/50
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3928 - loss: 2.5782
# Epoch 30: saving model to /kaggle/working/checkpoint_model_epoch_30.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3928 - loss: 2.5782
# Epoch 30: val_accuracy did not improve from 0.24431
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.3928 - loss: 2.5782 - val_accuracy: 0.2422 - val_loss: 3.7644 - learning_rate: 2.4300e-06
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3942 - loss: 2.5535
# Epoch 31: val_accuracy did not improve from 0.24431
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.3942 - loss: 2.5534 - val_accuracy: 0.2409 - val_loss: 3.7683 - learning_rate: 2.4300e-06
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4078 - loss: 2.5609
# Epoch 32: val_accuracy did not improve from 0.24431
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.4077 - loss: 2.5609 - val_accuracy: 0.2395 - val_loss: 3.7658 - learning_rate: 7.2900e-07
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4089 - loss: 2.5569
# Epoch 33: val_accuracy did not improve from 0.24431
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.4088 - loss: 2.5569 - val_accuracy: 0.2388 - val_loss: 3.7663 - learning_rate: 7.2900e-07
# Epoch 34/50
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4095 - loss: 2.5480
# Epoch 34: val_accuracy did not improve from 0.24431
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4094 - loss: 2.5481 - val_accuracy: 0.2402 - val_loss: 3.7680 - learning_rate: 2.1870e-07
# Epoch 35/50
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3847 - loss: 2.5765
# Epoch 35: saving model to /kaggle/working/checkpoint_model_epoch_35.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3848 - loss: 2.5764
# Epoch 35: val_accuracy did not improve from 0.24431
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.3848 - loss: 2.5764 - val_accuracy: 0.2402 - val_loss: 3.7696 - learning_rate: 2.1870e-07
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4141 - loss: 2.5297
# Epoch 36: val_accuracy did not improve from 0.24431
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4141 - loss: 2.5297 - val_accuracy: 0.2402 - val_loss: 3.7673 - learning_rate: 6.5610e-08
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3977 - loss: 2.5395
# Epoch 37: val_accuracy did not improve from 0.24431
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.3978 - loss: 2.5396 - val_accuracy: 0.2409 - val_loss: 3.7665 - learning_rate: 6.5610e-08
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 27.

# %%
best_val_acc=max(history.history['val_accuracy'])
print(f"Best validation accuracy: {best_val_acc * 100:.2f}%")
# Out:
# Best validation accuracy: 24.43%

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Plot accuracy
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_ylim([0, 1])
axs[0].set_title('Training and Validation Accuracy')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].legend()
axs[0].grid(True)

# Plot loss
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Training and Validation Loss')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Evaluation**

# %%
# Evaluate on test data
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Accuracy (Top-1 Accuracy): {test_accuracy * 100:.2f}%")

# Predict on the entire test dataset
y_pred = np.argmax(model.predict(test_ds), axis=-1)
y_true = np.concatenate([np.argmax(y, axis=-1) for _, y in test_ds], axis=0)

cm = confusion_matrix(y_true, y_pred)

# Calculate accuracy for each class
per_class_accuracy = cm.diagonal() / cm.sum(axis=1)

average_accuracy_per_class = np.mean(per_class_accuracy)
print(f"Average Accuracy per Class: {average_accuracy_per_class * 100:.2f}%")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.2729 - loss: 3.6842
# Test Accuracy (Top-1 Accuracy): 23.67%
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step
# Average Accuracy per Class: 23.20%

# %%
def plot_and_predict(model, test_images, test_labels, filenames, num_images):
    plt.figure(figsize=(15, 10))
    rows = num_images // 6 + (num_images % 6 > 0)
    for i in range(num_images):
        idx = random.randint(0, len(test_images) - 1)
        img = test_images[idx]
        filename = filenames[idx]
        true_label = np.argmax(test_labels[idx])

        prediction = model.predict(np.expand_dims(img, axis=0))
        predicted_label = np.argmax(prediction)
        
        if true_label == predicted_label:
            color = 'green'
        else:
            color = 'red'

        plt.subplot(rows, 6, i + 1)
        plt.imshow((img + 1) / 2)
        plt.title(f"Filename: {filename}\nTrue: {true_label}, Prediction: {predicted_label}", color=color)
        plt.axis('off')

    plt.tight_layout(pad=0, h_pad=0, w_pad=1.0)
    plt.suptitle("Prediction on testing images")
    plt.show()

# Load filenames from the text file
filenames = [os.path.basename(line.split()[0]) for line in open(test_txt).readlines()]

plot_and_predict(model, test_images, test_labels, filenames, num_images=12)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
